# %% [markdown]
# Olá, Bruno
#
# Meu nome é Ramon. Fico feliz em revisar seu projeto. Ao ao longo do texto farei algumas observações sobre melhorias no código e também farei comentários sobre suas percepções sobre o assunto. Estarei aberto a feedbacks e discussões sobre o tema.
#
# **Peço que mantenha e não altere os comentários que eu fizer por aqui para que possamos nos localizar posteriormente, ok?**
#
# Mais uma coisa, vamos utilizar um código de cores para você entender os meus feedbacks no seu notebook. Funciona assim:
#
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Sucesso. Tudo foi feito corretamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Alerta não crítco, mas que pode ser corrigido para melhoria geral no seu código/análise
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Erro que precisa ser consertado, caso contrário seu projeto **não** será aceito.
# </div>
#
# Você pode me responder usando isso:
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# </div>
#
# ###
#
# <div class="alert alert-block alert-success">
# <b>Comentário Geral do Revisor</b> <a class="tocSkip"></a>
#
# Obrigado por enviar seu projeto.
#
# Parabéns, você fez um bom trabalho.
#
# Como pontos fortes do projeto, destaco:
# - Código simples e eficiente (sem loop desnecessário)
# - Uso adequado dos recursos da lição
#
#
# <span class="text-danger">Porém, há espaço para melhorias conforme os itens apontados anteriormente. Destaco os  pontos a seguir: </span>
#  * <span class="text-danger"> Erro no merge; Ajustar teste de hipótese; erro de execução; </span>
#
#
# Portanto, sugiro que você corrija os pontos indicados.
#
# Se você tiver alguma dúvida sobre de algo que você não tenha entendido, sinta-se à vontade para perguntar ao tutor ou deixar um comentário em **azul** para que, na próxima iteração, eu possa responder.
#
# Conte conosco. Lembre-se de que você pode tirar dúvidas com revisores usando os comentários ou buscar ajuda de um tutor.
# Bom trabalho.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário final do revisor: </b> <a class="tocSkip"></a>
#
# Tudo certo agora. Deixei respostas para a pergunta que você deixou. Desejo sucesso na jornada. Parabéns pelo empenho.
# </div>

# %% [markdown]
# # Qual é o melhor plano?
#
# Você trabalha como analista para a empresa de telecomunicações Megaline. A empresa oferece aos clientes dois planos pré-pagos: Surf e Ultimate. O departamento comercial quer saber qual dos planos gera mais receita para ajustar o orçamento de publicidade.
#
# Você vai realizar uma análise preliminar dos planos com base em uma pequena seleção de clientes. Você terá dados de 500 clientes da Megaline: que clientes são, de onde eles são, qual plano usam e o número de chamadas e mensagens realizadas em 2018. Seu trabalho é analisar o comportamento dos clientes e determinar qual plano pré-pago gera mais receita.

# %% [markdown]
# [Fornecemos alguns comentários para guiar sua linha de raciocínio enquanto você trabalha neste projeto. Entretanto, certifique-se de remover todos os comentários entre colchetes antes de enviar o projeto.]
#
# [Antes de começar a análise dos dados, explique com suas próprias palavras o propósito do projeto e as ações que planeja realizar.]
#
# [Tenha em mente que estudar, modificar e analisar dados é um processo iterativo. É normal retornar a etapas anteriores e corrigir/expandir algo para permitir as próximas etapas.]

# %% [markdown]
# ## Inicialização

# %%
import pandas as pd
from scipy import stats as st
import seaborn as sns
import numpy as np
from math import factorial
import math as mt
from matplotlib import pyplot as plt

# Carregando todas as bibliotecas

# %% [markdown]
# ## Carregue os dados

# %%
df_calls = pd.read_csv("/datasets/megaline_calls.csv")
df_internet = pd.read_csv("/datasets/megaline_internet.csv")
df_msg = pd.read_csv("/datasets/megaline_messages.csv")
df_plans = pd.read_csv("/datasets/megaline_plans.csv")
df_users = pd.read_csv("/datasets/megaline_users.csv")

# Carregue os arquivos de dados em diferentes DataFrames

# %% [markdown]
# ## Prepare os dados

# %%
# vou verificar a quantidade de chamadas, mensagens e internet usados por mês e deixar as datas de acordo.

# %% [markdown]
# [Os dados deste projeto estão divididos em várias tabelas. Explore cada uma para obter uma compreensão inicial dos dados. Faça correções em cada tabela, se necessário.]

# %% [markdown]
# ## Planos

# %%
df_plans.info()# Imprima informações gerais/resumo sobre o DataFrame dos planos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   usd_monthly_pay        2 non-null      int64
#  4   usd_per_gb             2 non-null      int64
#  5   usd_per_message        2 non-null      float64
#  6   usd_per_minute         2 non-null      float64
#  7   plan_name              2 non-null      object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 256.0+ bytes

# %%
df_plans # Imprima uma amostra de dados dos planos
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# [Descreva o que você nota sobre as informações gerais e sobre a amostra de dados impressa acima. Existem problemas (tipos de dados inadequados, dados ausentes, etc.) que precisam de mais investigação e alterações? Como isso pode ser corrigido?]

# %%
# Transformei a coluna de megas por mês para Gigabytes

# %% [markdown]
# ## Corrija os dados

# %% [markdown]
# [Corrija problemas óbvios com os dados conforme as observações iniciais.]

# %%
df_plans["gb_per_month_included"]=df_plans["mb_per_month_included"]/1024

df_plans
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name  \
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate
#
#    gb_per_month_included
# 0                   15.0
# 1                   30.0

# %% [markdown]
# ## Enriqueça os dados

# %% [markdown]
# [Inclua fatores adicionais aos dados se você acredita que eles podem ser úteis.]

# %%
#adicionado em cima

# %% [markdown]
# ## Usuários

# %%
df_users.info()# Imprima informações gerais/resumo sobre o DataFrame dos usuários
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    object
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %%
df_users.sample(n=20)# Imprima uma amostra de dados dos usuários
# Out:
#      user_id first_name  last_name  age  \
# 77      1077       Chau    Webster   23
# 103     1103     Moises      Weeks   28
# 283     1283       Alan    Burgess   38
# 158     1158      Robin   Thornton   20
# 126     1126   Jermaine    Mcguire   68
# 382     1382       Luci       Kidd   49
# 95      1095    Lilliam   Alvarado   55
# 469     1469       Rory      Nixon   75
# 363     1363     Sandee       Lott   33
# 312     1312       Kory    Emerson   42
# 398     1398     German   Thompson   30
# 223     1223   Patience     Wilson   37
# 364     1364    Clarine     Bonner   75
# 373     1373    Lindsey  Dickerson   21
# 243     1243     Isaias    Compton   71
# 348     1348       Carl   Rutledge   60
# 221     1221   Mckenzie  Wilkinson   18
# 375     1375       Andy     Holden   69
# 137     1137    Allegra    Hopkins   20
# 467     1467   Nickolas     Deleon   64
#
#                                                 city    reg_date      plan  \
# ...

# %%
df_users["city"]
# Out:
# 0          Atlanta-Sandy Springs-Roswell, GA MSA
# 1                Seattle-Tacoma-Bellevue, WA MSA
# 2           Las Vegas-Henderson-Paradise, NV MSA
# 3                                  Tulsa, OK MSA
# 4                Seattle-Tacoma-Bellevue, WA MSA
#                          ...
# 495    New York-Newark-Jersey City, NY-NJ-PA MSA
# 496                 New Orleans-Metairie, LA MSA
# 497       Los Angeles-Long Beach-Anaheim, CA MSA
# 498    New York-Newark-Jersey City, NY-NJ-PA MSA
# 499            Orlando-Kissimmee-Sanford, FL MSA
# Name: city, Length: 500, dtype: object

# %%
# Existe no primeiro e no último nome, letras começando com maiúsculas e depois minúsculas. Vou padronizar tudo para minúsculas, assim como para cidades.

# %% [markdown]
# [Descreva o que você nota sobre as informações gerais e sobre a amostra de dados impressa acima. Existem problemas (tipos de dados inadequados, dados ausentes, etc.) que precisam de mais investigação e alterações? Como isso pode ser corrigido?]

# %% [markdown]
# ### Corrija os dados

# %% [markdown]
# [Corrija problemas óbvios com os dados conforme as observações iniciais.]

# %%
df_users["first_name"]= df_users["first_name"].str.lower()
df_users
# Out:
#      user_id first_name   last_name  age  \
# 0       1000   anamaria       Bauer   45
# 1       1001     mickey   Wilkerson   28
# 2       1002     carlee     Hoffman   36
# 3       1003   reynaldo     Jenkins   52
# 4       1004    leonila    Thompson   40
# ..       ...        ...         ...  ...
# 495     1495      fidel      Sharpe   67
# 496     1496      ariel    Shepherd   49
# 497     1497      donte     Barrera   49
# 498     1498       scot  Williamson   51
# 499     1499      shena     Dickson   37
#
#                                           city    reg_date      plan  \
# 0        Atlanta-Sandy Springs-Roswell, GA MSA  2018-12-24  ultimate
# 1              Seattle-Tacoma-Bellevue, WA MSA  2018-08-13      surf
# 2         Las Vegas-Henderson-Paradise, NV MSA  2018-10-21      surf
# 3                                Tulsa, OK MSA  2018-01-28      surf
# 4              Seattle-Tacoma-Bellevue, WA MSA  2018-05-23      surf
# ...

# %%
df_users["last_name"]= df_users["last_name"].str.lower()
df_users
# Out:
#      user_id first_name   last_name  age  \
# 0       1000   anamaria       bauer   45
# 1       1001     mickey   wilkerson   28
# 2       1002     carlee     hoffman   36
# 3       1003   reynaldo     jenkins   52
# 4       1004    leonila    thompson   40
# ..       ...        ...         ...  ...
# 495     1495      fidel      sharpe   67
# 496     1496      ariel    shepherd   49
# 497     1497      donte     barrera   49
# 498     1498       scot  williamson   51
# 499     1499      shena     dickson   37
#
#                                           city    reg_date      plan  \
# 0        Atlanta-Sandy Springs-Roswell, GA MSA  2018-12-24  ultimate
# 1              Seattle-Tacoma-Bellevue, WA MSA  2018-08-13      surf
# 2         Las Vegas-Henderson-Paradise, NV MSA  2018-10-21      surf
# 3                                Tulsa, OK MSA  2018-01-28      surf
# 4              Seattle-Tacoma-Bellevue, WA MSA  2018-05-23      surf
# ...

# %%
df_users["city"]= df_users["city"].str.lower()
df_users
# Out:
#      user_id first_name   last_name  age  \
# 0       1000   anamaria       bauer   45
# 1       1001     mickey   wilkerson   28
# 2       1002     carlee     hoffman   36
# 3       1003   reynaldo     jenkins   52
# 4       1004    leonila    thompson   40
# ..       ...        ...         ...  ...
# 495     1495      fidel      sharpe   67
# 496     1496      ariel    shepherd   49
# 497     1497      donte     barrera   49
# 498     1498       scot  williamson   51
# 499     1499      shena     dickson   37
#
#                                           city    reg_date      plan  \
# 0        atlanta-sandy springs-roswell, ga msa  2018-12-24  ultimate
# 1              seattle-tacoma-bellevue, wa msa  2018-08-13      surf
# 2         las vegas-henderson-paradise, nv msa  2018-10-21      surf
# 3                                tulsa, ok msa  2018-01-28      surf
# 4              seattle-tacoma-bellevue, wa msa  2018-05-23      surf
# ...

# %% [markdown]
# ### Enriqueça os dados

# %% [markdown]
# [Inclua fatores adicionais aos dados se você acredita que eles podem ser úteis.]

# %% [markdown]
# ## Chamadas

# %%
df_calls.info()# Imprima informações gerais/resumo sobre o DataFrame das chamadas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB

# %%
df_calls.sample(n=20)# Imprima uma amostra de dados das chamadas
# Out:
#               id  user_id   call_date  duration
# 36765    1140_49     1140  2018-06-28     15.81
# 56569   1202_836     1202  2018-10-04      2.78
# 99797   1358_141     1358  2018-08-01      7.69
# 61435    1222_82     1222  2018-09-30      0.00
# 30578   1114_477     1114  2018-11-29     18.58
# 62814   1226_213     1226  2018-11-20      1.14
# 74635   1263_619     1263  2018-04-29      4.43
# 8556     1040_34     1040  2018-12-26     17.26
# 6445      1031_7     1031  2018-07-30     14.40
# 29457    1111_93     1111  2018-10-30      0.00
# 133442  1483_257     1483  2018-08-09      0.18
# 121505  1427_173     1427  2018-12-27      8.71
# 54946   1196_844     1196  2018-09-26      6.60
# 93856    1335_86     1335  2018-11-22     17.36
# 113443   1399_66     1399  2018-06-13      3.46
# 114645  1401_463     1401  2018-09-11     13.31
# 135087  1490_187     1490  2018-08-16      4.91
# 8337    1039_277     1039  2018-08-26      3.96
# 113036  1397_779     1397  2018-10-25      3.74
# ...

# %%
# A duração deve estar em minutos. Portanto, uma alteração de horas para minutos nessa coluna deve ser realizada.

# %% [markdown]
# [Descreva o que você nota sobre as informações gerais e sobre a amostra de dados impressa acima. Existem problemas (tipos de dados inadequados, dados ausentes, etc.) que precisam de mais investigação e alterações? Como isso pode ser corrigido?]

# %% [markdown]
# ### Corrija os dados

# %% [markdown]
# [Corrija problemas óbvios com os dados conforme as observações iniciais.]

# %%
df_calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB

# %% [markdown]
# ### Enriqueça os dados

# %% [markdown]
# [Inclua fatores adicionais aos dados se você acredita que eles podem ser úteis.]

# %%
# Vou já transformas as datas em mês ano.
df_calls["call_date"]= pd.to_datetime(df_calls["call_date"], format="%Y-%m-%d")
df_calls.sample(n=20)
# Out:
#               id  user_id  call_date  duration
# 29014    1110_65     1110 2018-11-27     10.10
# 24874   1095_207     1095 2018-12-05      9.46
# 137101   1498_22     1498 2018-09-08      4.60
# 22851    1083_49     1083 2018-11-15      0.00
# 111928  1393_113     1393 2018-11-12      0.99
# 114201  1400_551     1400 2018-03-10     10.41
# 17411   1066_521     1066 2018-08-17      0.00
# 112690  1397_306     1397 2018-09-30      0.17
# 60451    1218_20     1218 2018-12-26      0.09
# 93623   1334_991     1334 2018-05-10     10.44
# 101005  1361_107     1361 2018-08-10      1.85
# 135940  1493_102     1493 2018-11-21      0.00
# 126129  1446_396     1446 2018-12-20      3.49
# 38111   1142_334     1142 2018-10-25      0.00
# 123894  1437_653     1437 2018-12-18     14.32
# 40657   1150_280     1150 2018-11-26      9.84
# 67291   1241_127     1241 2018-10-18     10.09
# 24040   1090_219     1090 2018-12-02      0.00
# 5286    1022_552     1022 2018-10-25      6.40
# ...

# %%
df_calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  datetime64[ns]
#  3   duration   137735 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 4.2+ MB

# %% [markdown]
# ## Mensagens

# %%
df_msg.info()# Imprima informações gerais/resumo sobre o DataFrame das mensagens
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df_msg.sample(n=20) # Imprima uma amostra dos dados das mensagens
# Out:
#              id  user_id message_date
# 42078   1271_56     1271   2018-12-27
# 61518  1384_664     1384   2018-06-26
# 46151   1314_39     1314   2018-12-11
# 51154  1331_329     1331   2018-12-17
# 26466  1159_469     1159   2018-09-01
# 40818  1261_487     1261   2018-10-29
# 3522   1036_357     1036   2018-12-08
# 66962    1435_0     1435   2018-11-29
# 12459  1081_214     1081   2018-07-05
# 33059   1206_53     1206   2018-09-14
# 36463  1242_135     1242   2018-10-27
# 69420  1451_117     1451   2018-12-02
# 48996   1327_89     1327   2018-11-22
# 67093  1435_131     1435   2018-12-10
# 37431  1247_595     1247   2018-09-23
# 53207  1339_341     1339   2018-07-04
# 75237  1489_312     1489   2018-12-09
# 64016  1408_141     1408   2018-03-24
# 31813  1196_299     1196   2018-08-11
# 14252  1098_268     1098   2018-10-07

# %% [markdown]
# [Descreva o que você nota sobre as informações gerais e sobre a amostra de dados impressa acima. Existem problemas (tipos de dados inadequados, dados ausentes, etc.) que precisam de mais investigação e alterações? Como isso pode ser corrigido?]

# %%
# nenhum erro encontrado aqui.

# %% [markdown]
# ### Corrija os dados

# %% [markdown]
# [Corrija problemas óbvios com os dados conforme as observações iniciais.]

# %% [markdown]
# ### Enriqueça os dados

# %% [markdown]
# [Inclua fatores adicionais aos dados se você acredita que eles podem ser úteis.]

# %%
df_msg["message_date"]= pd.to_datetime(df_msg["message_date"], format="%Y-%m-%d")

# %% [markdown]
# ## Internet

# %%
df_internet.info()# Imprima informações gerais/resumo sobre o DataFrame da internet
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  object
#  3   mb_used       104825 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
df_internet.sample(n=20)#  Imprima uma amostra de dados para o tráfego da internet
# Out:
#              id  user_id session_date  mb_used
# 35324   1160_28     1160   2018-06-04   490.12
# 59657  1268_326     1268   2018-08-25   714.48
# 25715  1120_253     1120   2018-08-31   577.68
# 5935    1032_96     1032   2018-11-30   557.22
# 97484    1460_8     1460   2018-08-13   419.14
# 87108  1403_456     1403   2018-06-10   692.27
# 86300  1400_437     1400   2018-08-15   281.46
# 66151  1305_378     1305   2018-10-24   109.65
# 11293  1055_298     1055   2018-05-15   362.96
# 61102  1277_405     1277   2018-09-07   178.11
# 72098  1336_112     1336   2018-10-03     0.00
# 3824   1022_235     1022   2018-12-07     9.06
# 18461  1082_166     1082   2018-09-14    82.65
# 92740  1433_124     1433   2018-10-14   384.51
# 32187  1145_323     1145   2018-12-17   328.11
# 98745  1466_226     1466   2018-07-02   242.11
# 96223   1450_19     1450   2018-12-14     0.00
# 61409   1279_23     1279   2018-11-21   363.14
# 82304   1385_55     1385   2018-07-30   156.72
# ...

# %% [markdown]
# [Descreva o que você nota sobre as informações gerais e sobre a amostra de dados impressa acima. Existem problemas (tipos de dados inadequados, dados ausentes, etc.) que precisam de mais investigação e alterações? Como isso pode ser corrigido?]

# %%
df_internet["gb_used"] = df_internet["mb_used"]/1024
df_internet#Transformando megas para giga usados
# Out:
#               id  user_id session_date  mb_used   gb_used
# 0        1000_13     1000   2018-12-29    89.86  0.087754
# 1       1000_204     1000   2018-12-31     0.00  0.000000
# 2       1000_379     1000   2018-12-28   660.40  0.644922
# 3       1000_413     1000   2018-12-26   270.99  0.264639
# 4       1000_442     1000   2018-12-27   880.22  0.859590
# ...          ...      ...          ...      ...       ...
# 104820  1499_215     1499   2018-10-20   218.06  0.212949
# 104821  1499_216     1499   2018-12-30   304.72  0.297578
# 104822  1499_217     1499   2018-09-22   292.75  0.285889
# 104823  1499_218     1499   2018-12-07     0.00  0.000000
# 104824  1499_219     1499   2018-12-24   758.31  0.740537
#
# [104825 rows x 5 columns]

# %% [markdown]
# ### Corrija os dados

# %% [markdown]
# [Corrija problemas óbvios com os dados conforme as observações iniciais.]

# %% [markdown]
# ### Enriqueça os dados

# %% [markdown]
# [Inclua fatores adicionais aos dados se você acredita que eles podem ser úteis.]

# %%
df_internet["session_date"]= pd.to_datetime(df_internet["session_date"], format="%Y-%m-%d")

# %% [markdown]
# ## Estude as condições dos planos

# %% [markdown]
# [É fundamental entender como os planos funcionam, ou seja, como as cobranças dos usuários são feitas com base na assinatura. Sugerimos imprimir as informações sobre os planos para visualizar novamente as condições.]

# %%
df_plans# Imprima as condições dos planos e certifique-se de que elas fazem sentido para você
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name  \
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate
#
#    gb_per_month_included
# 0                   15.0
# 1                   30.0

# %% [markdown]
# ## Agregue os dados por usuário
#
# [Agora, como os dados estão limpos, os agregue por usuário e por período para ter apenas um registro dessas informações. Isso vai facilitar muito as próximas análises.]

# %%
df_calls["month"] = df_calls["call_date"].dt.month
df_month_calls = df_calls.groupby(['user_id', 'month'])["id"].count().reset_index(name="num_calls")    # Calcule o número de chamadas feitas por cada usuário por mês. Salve o resultado.
df_month_calls
# Out:
#       user_id  month  num_calls
# 0        1000     12         16
# 1        1001      8         27
# 2        1001      9         49
# 3        1001     10         65
# 4        1001     11         64
# ...       ...    ...        ...
# 2253     1498     12         39
# 2254     1499      9         41
# 2255     1499     10         53
# 2256     1499     11         45
# 2257     1499     12         65
#
# [2258 rows x 3 columns]

# %%
df_calls["month"] = df_calls["call_date"].dt.month


df_month_min = df_calls.groupby(['user_id', 'month'])["duration"].sum().reset_index()

df_month_min.sample(20) # Calcule a quantidade de minutos gastos por cada usuário por mês. Salve o resultado.
# Out:
#       user_id  month  duration
# 1906     1414      9    435.32
# 1249     1268      9    439.48
# 980      1211     10    249.13
# 131      1036     11    488.04
# 512      1110      8    257.67
# 133      1037     12    437.66
# 772      1164     12    332.21
# 1950     1425     10    245.99
# 1016     1219     12    670.63
# 200      1049      9    335.44
# 2252     1498     11    208.99
# 2150     1474     12    267.54
# 390      1082      5    661.15
# 2140     1472      5    578.91
# 2115     1467      5    310.49
# 265      1060     12    749.08
# 18       1005     12    470.22
# 1623     1359      2    248.30
# 1719     1377     11    316.80
# 1595     1353     12    341.41

# %%
df_msg["month"] = df_msg["message_date"].dt.month


df_month_msg = df_msg.groupby(["user_id", "month"])["id"].count().reset_index(name="num_msg") 

df_month_msg # Calcule o número de mensagens enviadas por cada usuário por mês. Salve o resultado.
# Out:
#       user_id  month  num_msg
# 0        1000     12       11
# 1        1001      8       30
# 2        1001      9       44
# 3        1001     10       53
# 4        1001     11       36
# ...       ...    ...      ...
# 1801     1496      9       21
# 1802     1496     10       18
# 1803     1496     11       13
# 1804     1496     12       11
# 1805     1497     12       50
#
# [1806 rows x 3 columns]

# %%
df_internet["month"] = df_internet["session_date"].dt.month


df_month_internet = df_internet.groupby(["user_id", "month"])["gb_used"].sum().reset_index()  # Calcule o volume de tráfego de internet usado por cada usuário por mês. Salve o resultado.

df_month_internet
# Out:
#       user_id  month    gb_used
# 0        1000     12   1.856904
# 1        1001      8   6.756982
# 2        1001      9  13.002754
# 3        1001     10  21.807119
# 4        1001     11  18.070605
# ...       ...    ...        ...
# 2272     1498     12  22.595400
# 2273     1499      9  12.680430
# 2274     1499     10  19.035576
# 2275     1499     11  16.419756
# 2276     1499     12  21.542197
#
# [2277 rows x 3 columns]

# %% [markdown]
# [Coloque os dados agregados em um DataFrame para que cada registro nele represente o que cada usuário consumiu em um determinado mês.]

# %%
df_merge1 = df_month_calls.merge(df_month_msg, on= ['user_id', "month"], how='outer')
df_merge1.sample(20)

# juntei nessa célula as chamadas com as mensagens
# Out:
#       user_id  month  num_calls  num_msg
# 658      1142     12       56.0     47.0
# 969      1209      9      105.0     31.0
# 1026     1221     12       20.0     11.0
# 1615     1358      5       75.0      6.0
# 167      1043      6       12.0     30.0
# 444      1096     12       21.0     14.0
# 762      1163     11       82.0     10.0
# 664      1144      9       70.0     74.0
# 1423     1316     12       21.0     70.0
# 1643     1362      2      106.0     58.0
# 1169     1254      9       59.0    112.0
# 350      1075      9       17.0     48.0
# 1004     1215     10      123.0     96.0
# 425      1090     10       74.0     21.0
# 1012     1217     11       94.0      NaN
# 1437     1320     11      140.0     72.0
# 798      1171      6       47.0      NaN
# 1930     1418     12       42.0      NaN
# 1443     1321     10       63.0      NaN
# 553      1120      5       58.0     48.0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Precisa usar how='outer' pois pode haver usuário na esquerda que não tenha registro na direita. Deixo este link como referência: https://www.educba.com/python-pandas-join/
# </div>

# %% [markdown]
# </div>
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# correto
#
# </div>

# %%
df_merge2= df_month_min.merge(df_month_internet, on=['user_id', "month"], how='outer')
df_merge2 #juntei aqui nessa célula os minutos com a quantidade utilizada de internet
# Out:
#       user_id  month  duration    gb_used
# 0        1000     12    116.83   1.856904
# 1        1001      8    171.14   6.756982
# 2        1001      9    297.69  13.002754
# 3        1001     10    374.11  21.807119
# 4        1001     11    404.59  18.070605
# ...       ...    ...       ...        ...
# 2287     1311      6       NaN   1.463701
# 2288     1349     10       NaN  12.786670
# 2289     1349     11       NaN  16.726816
# 2290     1349     12       NaN  12.734287
# 2291     1361      5       NaN   1.484072
#
# [2292 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Precisa usar how='outer' pois pode haver usuário na esquerda que não tenha registro na direita. Deixo este link como referência: https://www.educba.com/python-pandas-join/
# </div>

# %% [markdown]
# </div>
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# correto
#
# </div>

# %%
df_merge3= df_merge1.merge(df_merge2, on=['user_id', "month"], how='outer')
df_merge3
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used
# 0        1000     12       16.0     11.0    116.83   1.856904
# 1        1001      8       27.0     30.0    171.14   6.756982
# 2        1001      9       49.0     44.0    297.69  13.002754
# 3        1001     10       65.0     53.0    374.11  21.807119
# 4        1001     11       64.0     36.0    404.59  18.070605
# ...       ...    ...        ...      ...       ...        ...
# 2288     1349     12        NaN     61.0       NaN  12.734287
# 2289     1361      5        NaN      2.0       NaN   1.484072
# 2290     1482     10        NaN      2.0       NaN        NaN
# 2291     1108     12        NaN      NaN       NaN   0.227705
# 2292     1311      6        NaN      NaN       NaN   1.463701
#
# [2293 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Precisa usar how='outer' pois pode haver usuário na esquerda que não tenha registro na direita. Deixo este link como referência: https://www.educba.com/python-pandas-join/
# </div>

# %% [markdown]
# </div>
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# correto
#
# </div>

# %%
df_merge4= df_merge3.merge(df_users[["user_id","plan"]], on='user_id', how='left')
df_merge4=df_merge4.rename(columns={"plan":"plan_name"})
df_merge4
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used plan_name
# 0        1000     12       16.0     11.0    116.83   1.856904  ultimate
# 1        1001      8       27.0     30.0    171.14   6.756982      surf
# 2        1001      9       49.0     44.0    297.69  13.002754      surf
# 3        1001     10       65.0     53.0    374.11  21.807119      surf
# 4        1001     11       64.0     36.0    404.59  18.070605      surf
# ...       ...    ...        ...      ...       ...        ...       ...
# 2288     1349     12        NaN     61.0       NaN  12.734287      surf
# 2289     1361      5        NaN      2.0       NaN   1.484072      surf
# 2290     1482     10        NaN      2.0       NaN        NaN  ultimate
# 2291     1108     12        NaN      NaN       NaN   0.227705  ultimate
# 2292     1311      6        NaN      NaN       NaN   1.463701  ultimate
#
# [2293 rows x 7 columns]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Precisa usar how='right'para garantir que todo usuário estará na amostra. Deixo este link como referência: https://www.educba.com/python-pandas-join/
# </div>

# %% [markdown]
# </div>
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# correto
#
# </div>

# %%
#Após conversar com o Pedro, não seria how="left"?

# %%
df_plans
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name  \
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate
#
#    gb_per_month_included
# 0                   15.0
# 1                   30.0

# %%
df_merge5 = df_merge4.merge(df_plans, on= "plan_name", how="inner")
df_merge5
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used plan_name  \
# 0        1000     12       16.0     11.0    116.83   1.856904  ultimate
# 1        1006     11        2.0     15.0      9.32   2.019893  ultimate
# 2        1006     12        9.0    139.0     54.79  31.366035  ultimate
# 3        1008     10       71.0     21.0    450.21  16.706045  ultimate
# 4        1008     11       63.0     37.0    422.81  23.121797  ultimate
# ...       ...    ...        ...      ...       ...        ...       ...
# 2288     1194     12        NaN     56.0       NaN  30.359854      surf
# 2289     1349     10        NaN     76.0       NaN  12.786670      surf
# 2290     1349     11        NaN     72.0       NaN  16.726816      surf
# 2291     1349     12        NaN     61.0       NaN  12.734287      surf
# 2292     1361      5        NaN      2.0       NaN   1.484072      surf
#
#       messages_included  mb_per_month_included  minutes_included  \
# ...

# %%
def chargeable_calls (row):
    plan = row['plan_name'] 
    minutes_used = row['duration'] 
    if plan == 'surf': 
        if minutes_used > 500: 
            chargeable = minutes_used - 500 
        else:
            chargeable = 0 
    if plan == 'ultimate': 
        if minutes_used > 3000: 
                chargeable = minutes_used - 3000
        else:
            chargeable = 0
    return chargeable

# %%
df_merge5["chargeable_calls"] = df_merge5.apply(chargeable_calls,axis=1)
df_merge5
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used plan_name  \
# 0        1000     12       16.0     11.0    116.83   1.856904  ultimate
# 1        1006     11        2.0     15.0      9.32   2.019893  ultimate
# 2        1006     12        9.0    139.0     54.79  31.366035  ultimate
# 3        1008     10       71.0     21.0    450.21  16.706045  ultimate
# 4        1008     11       63.0     37.0    422.81  23.121797  ultimate
# ...       ...    ...        ...      ...       ...        ...       ...
# 2288     1194     12        NaN     56.0       NaN  30.359854      surf
# 2289     1349     10        NaN     76.0       NaN  12.786670      surf
# 2290     1349     11        NaN     72.0       NaN  16.726816      surf
# 2291     1349     12        NaN     61.0       NaN  12.734287      surf
# 2292     1361      5        NaN      2.0       NaN   1.484072      surf
#
#       messages_included  mb_per_month_included  minutes_included  \
# ...

# %%
len(df_merge5.query("chargeable_calls != 0"))
# Out:
# 484

# %%
def chargeable_data (row):
    plan = row['plan_name'] 
    data_used = row['gb_used'] 
    if plan == 'surf': 
        if data_used > 15: 
            chargeable = data_used - 15 
        else:
            chargeable = 0 
    if plan == 'ultimate': 
        if data_used > 30: 
                chargeable = data_used - 30
        else:
                chargeable = 0
    return chargeable

# %%
df_merge5["chargeable_data"] = df_merge5.apply(chargeable_data,axis=1)
df_merge5
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used plan_name  \
# 0        1000     12       16.0     11.0    116.83   1.856904  ultimate
# 1        1006     11        2.0     15.0      9.32   2.019893  ultimate
# 2        1006     12        9.0    139.0     54.79  31.366035  ultimate
# 3        1008     10       71.0     21.0    450.21  16.706045  ultimate
# 4        1008     11       63.0     37.0    422.81  23.121797  ultimate
# ...       ...    ...        ...      ...       ...        ...       ...
# 2288     1194     12        NaN     56.0       NaN  30.359854      surf
# 2289     1349     10        NaN     76.0       NaN  12.786670      surf
# 2290     1349     11        NaN     72.0       NaN  16.726816      surf
# 2291     1349     12        NaN     61.0       NaN  12.734287      surf
# 2292     1361      5        NaN      2.0       NaN   1.484072      surf
#
#       messages_included  mb_per_month_included  minutes_included  \
# ...

# %%
len(df_merge5.query("chargeable_data != 0"))
# Out:
# 952

# %%
def chargeable_msg (row):
    plan = row['plan_name'] 
    msg_used = row['num_msg'] 
    if plan == 'surf': 
        if msg_used > 50: 
            chargeable = msg_used - 50
        else:
            chargeable = 0 
    else: 
        if msg_used > 1000: 
            chargeable = msg_used - 1000
        else:
            chargeable = 0
    return chargeable

# %%
df_merge5["chargeable_msg"] = df_merge5.apply(chargeable_msg,axis=1)
df_merge5.sample(n=10)
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used plan_name  \
# 153      1091     10       42.0     35.0    294.25   3.547773  ultimate
# 1469     1241      9       72.0     20.0    457.15   8.969375      surf
# 1408     1216     12       49.0      NaN    355.20  15.320137      surf
# 1506     1254      8       79.0    106.0    513.68  20.418437      surf
# 453      1347     11       62.0     71.0    399.22  22.467959  ultimate
# 1282     1174      8       78.0     75.0    536.71  24.114219      surf
# 44       1036      9       54.0     83.0    276.65  14.623643  ultimate
# 2080     1421     11       72.0     67.0    417.71  16.239375      surf
# 737      1005     12       59.0     11.0    470.22  16.738447      surf
# 121      1069      9       26.0     51.0    208.79   8.098857  ultimate
#
#       messages_included  mb_per_month_included  minutes_included  \
# 153                1000                  30720              3000
# ...

# %%
len(df_merge5.query("chargeable_msg != 0"))
# Out:
# 340

# %% [markdown]
# [Calcule a receita mensal para cada usuário: subtraia o limite gratuito do pacote do número total de chamadas, mensagens de texto e dados; multiplique o resultado pelo valor do plano; adicione o preço mensal dependendo do plano. Importante: isso talvez não seja tão simples e necessite de várias linhas, considerando as condições do plano. Portanto, não se preocupe se você passar algum tempo nesta etapa.]

# %%
def receita (row):
    
    if "plan_name" == 'surf': 
        rev=(row["chargeable_msg"]*row["usd_per_message"])
    else: 
        rev=(row["chargeable_msg"]*row["usd_per_message"]) 
            
    return rev
df_merge5["rev_msg"]= df_merge5.apply(receita,axis=1)
df_merge5
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used plan_name  \
# 0        1000     12       16.0     11.0    116.83   1.856904  ultimate
# 1        1006     11        2.0     15.0      9.32   2.019893  ultimate
# 2        1006     12        9.0    139.0     54.79  31.366035  ultimate
# 3        1008     10       71.0     21.0    450.21  16.706045  ultimate
# 4        1008     11       63.0     37.0    422.81  23.121797  ultimate
# ...       ...    ...        ...      ...       ...        ...       ...
# 2288     1194     12        NaN     56.0       NaN  30.359854      surf
# 2289     1349     10        NaN     76.0       NaN  12.786670      surf
# 2290     1349     11        NaN     72.0       NaN  16.726816      surf
# 2291     1349     12        NaN     61.0       NaN  12.734287      surf
# 2292     1361      5        NaN      2.0       NaN   1.484072      surf
#
#       messages_included  mb_per_month_included  minutes_included  \
# ...

# %%
def receita (row):
    
    if "plan_name" == 'surf': 
        rev=(row["chargeable_calls"]*row["usd_per_minute"])
    else: 
        rev=(row["chargeable_calls"]*row["usd_per_minute"]) 
            
    return rev
df_merge5["rev_min"]= df_merge5.apply(receita,axis=1)
df_merge5
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used plan_name  \
# 0        1000     12       16.0     11.0    116.83   1.856904  ultimate
# 1        1006     11        2.0     15.0      9.32   2.019893  ultimate
# 2        1006     12        9.0    139.0     54.79  31.366035  ultimate
# 3        1008     10       71.0     21.0    450.21  16.706045  ultimate
# 4        1008     11       63.0     37.0    422.81  23.121797  ultimate
# ...       ...    ...        ...      ...       ...        ...       ...
# 2288     1194     12        NaN     56.0       NaN  30.359854      surf
# 2289     1349     10        NaN     76.0       NaN  12.786670      surf
# 2290     1349     11        NaN     72.0       NaN  16.726816      surf
# 2291     1349     12        NaN     61.0       NaN  12.734287      surf
# 2292     1361      5        NaN      2.0       NaN   1.484072      surf
#
#       messages_included  mb_per_month_included  minutes_included  \
# ...

# %%
def receita (row):
    
    if "plan_name" == 'surf': 
        rev=(row["chargeable_data"]*row["usd_per_gb"])
    else: 
        rev=(row["chargeable_data"]*row["usd_per_gb"]) 
            
    return rev
df_merge5["rev_data"]= df_merge5.apply(receita,axis=1)
df_merge5
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used plan_name  \
# 0        1000     12       16.0     11.0    116.83   1.856904  ultimate
# 1        1006     11        2.0     15.0      9.32   2.019893  ultimate
# 2        1006     12        9.0    139.0     54.79  31.366035  ultimate
# 3        1008     10       71.0     21.0    450.21  16.706045  ultimate
# 4        1008     11       63.0     37.0    422.81  23.121797  ultimate
# ...       ...    ...        ...      ...       ...        ...       ...
# 2288     1194     12        NaN     56.0       NaN  30.359854      surf
# 2289     1349     10        NaN     76.0       NaN  12.786670      surf
# 2290     1349     11        NaN     72.0       NaN  16.726816      surf
# 2291     1349     12        NaN     61.0       NaN  12.734287      surf
# 2292     1361      5        NaN      2.0       NaN   1.484072      surf
#
#       messages_included  mb_per_month_included  minutes_included  ...  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Está correto. Porém, o ideal é ter uma única função para calcular o custo. Além disso, em cada função com prefixo chargeable_ há valores hardcoded, o que não é uma boa prática. Imagine se um dos valores mudar? O código quebra. Então o ideal é ler esses valores do dataset fornecido.
# </div>

# %%
#O QUE SERIA VALORES HARDCODED? SERIAM ESSES VALORES? SE SIM, SÓ COLOQUEI MAIS PERTO DA ABA PARA FINS DE CONSULTA. SÓ ESQUECI O MARDOWN.
#surf_monthly_charge = 20
#surf_monthly_minutes = 500
#surf_monthly_messages = 50
#surf_monthly_data = 15
#surf_call_charge = 0.03
#surf_message_charge = 0.03
#surf_data_charge = 10

#ultimate_monthly_charge = 70
#ultimate_monthly_minutes = 3000
#ultimate_monthly_messages = 1000
#ultimate_monthly_data = 30
#ultimate_call_charge = 0.01
#ultimate_message_charge = 0.01
#ultimate_data_charge = 7

#PODE POR FAVOR ME DIZER COMO FICARIA O CÓDICO COM UMA ÚNICA FUNÇÃO PARA CALCULAR O CUSTO?

# %% [markdown]
# </div>
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# - Comentário de código é usado para comentar código. No caso acima, o ideal é usar markdown em azul para se comunicar com os revisores.
# - A ideia é fazer um merge com os gastos mensais e o csv que contém informação sobre o plano, então você cria uma função que vai receber uma linha dessa tabela e acessar a informação dos planos e dos gastos para calcular a receita total. Outra opção é acessar o dataframe de planos. Vou deixar um código abaixo
# - Código harcoded é fixar valores diretamente no código. No código acima, o ideal é ler do csv em vez de definir na variável. Porém, você explicou que colocou ali apenas para sua leitura.
#
# </div>

# %%
# def calcular_receita(row):
#     plan = df_plans[df_plans["plan_name"] == row["plan"]].iloc[0]
    
#     custo_mensal = plan["usd_monthly_pay"]
#     custo_minuto = plan["usd_per_minute"]
#     custo_mensagem = plan["usd_per_message"]
#     custo_gb = plan["usd_per_gb"]
    
#     minutos_excedentes = max(0, row["total_minutes"] - plan["minutes_included"])
#     mensagens_excedentes = max(0, row["messages_count"] - plan["messages_included"])
#     dados_excedentes = max(0, (row["total_mb_used"] - plan["mb_per_month_included"]) / 1024)
    
#     custo_extra = (minutos_excedentes * custo_minuto) + (mensagens_excedentes * custo_mensagem) + (dados_excedentes * custo_gb)
#     return custo_mensal + custo_extra

# %% [markdown]
# ## Estude o comportamento do usuário

# %% [markdown]
# [Calcule algumas estatísticas descritivas úteis para os dados agregados, o que costuma revelar uma imagem geral capturada pelos dados. Desenhe gráficos úteis para ajudar na compreensão. Já que a tarefa principal é comparar os planos e decidir qual é mais rentável, as estatísticas e os gráficos devem ser calculados por plano.]
#
# [Existem dicas relevantes nos comentários para as chamadas. Essas dicas não foram fornecidas para as mensagens e internet, mas o princípio do estudo estatístico é o mesmo em todos os casos.]

# %% [markdown]
# ### Chamadas

# %%
df_media_min_mes = df_merge5.groupby(['plan_name', 'month'])["duration"].mean().reset_index(name= "mean")# Compare a duração média das chamadas de cada plano para cada mês. Crie um gráfico de barras para visualizar o resultado.
df_media_min_mes
# Out:
#    plan_name  month        mean
# 0       surf      1  192.840000
# 1       surf      2  280.851111
# 2       surf      3  310.970000
# 3       surf      4  332.380000
# 4       surf      5  387.108000
# 5       surf      6  411.450625
# 6       surf      7  428.060917
# 7       surf      8  394.474717
# 8       surf      9  397.133298
# 9       surf     10  414.435733
# 10      surf     11  408.255415
# 11      surf     12  457.547074
# 12  ultimate      1  183.162500
# 13  ultimate      2  443.171667
# 14  ultimate      3  285.701667
# 15  ultimate      4  316.508095
# 16  ultimate      5  383.664828
# 17  ultimate      6  365.358222
# 18  ultimate      7  403.767288
# 19  ultimate      8  397.274789
# 20  ultimate      9  413.287326
# 21  ultimate     10  429.217238
# 22  ultimate     11  423.814683
# 23  ultimate     12  438.824832

# %%
df_media_min_mes= df_media_min_mes.reset_index()
df_media_min_mes.columns
# Out:
# Index(['index', 'plan_name', 'month', 'mean'], dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df_media_min_mes, x="month", y="mean", hue="plan_name")
plt.title("média por cliente mensal")
plt.xlabel("meses")
plt.ylabel("média mensal")

plt.legend(title="plano")
plt.show()

# %% [raw]
# # Compare o número de minutos que os usuários de cada plano necessitam a cada mês. Construa um histograma.
#
# # esta feito acima!

# %% [markdown]
# [Calcule a média e a variância da duração das chamadas para refletir se os usuários de cada plano possuem comportamentos diferentes sobre as chamadas.]

# %%
stats= df_merge5.groupby(['plan_name', 'month'])["duration"].agg(['mean', 'var'])# Calcule a média e a variância da duração mensal das chamadas

stats
# Out:
#                        mean           var
# plan_name month
# surf      1      192.840000  14795.440200
#           2      280.851111  46959.219961
#           3      310.970000  31821.317991
#           4      332.380000  45615.666796
#           5      387.108000  50778.127459
#           6      411.450625  39424.054023
#           7      428.060917  53364.540232
#           8      394.474717  46639.240873
#           9      397.133298  39785.302974
#           10     414.435733  44103.681803
#           11     408.255415  43560.874928
#           12     457.547074  53646.781898
# ultimate  1      183.162500  14991.369958
#           2      443.171667  48579.581537
#           3      285.701667  54273.917252
#           4      316.508095  31057.727496
#           5      383.664828  39290.610940
#           6      365.358222  33837.770156
#           7      403.767288  64844.426958
#           8      397.274789  47680.189425
#           9      413.287326  50994.505514
# ...

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='plan_name', y='duration', data=df_merge5)
plt.title('distribuição da duração mensal das chamadas')
plt.xlabel('Plano do Usuário')
plt.ylabel('Duração da Chamada (min)')

plt.show()# Faça um diagrama de caixa para visualizar a distribuição da duração mensal das chamadas

# %% [markdown]
# [Formule conclusões sobre como os usuários se comportam em termos de chamadas. O comportamento é diferente dependendo do plano?]

# %% [markdown]
# ### Mensagens

# %%
df_num_msg_mes = df_merge5.groupby(['plan_name', 'month'])["num_msg"].sum().reset_index(name= "numero_msg")# Compare o número de mensagens que os usuários de cada plano costumam enviar a cada mês
df_num_msg_mes
# Out:
#    plan_name  month  numero_msg
# 0       surf      1        21.0
# 1       surf      2       108.0
# 2       surf      3       351.0
# 3       surf      4       870.0
# 4       surf      5      1849.0
# 5       surf      6      2454.0
# 6       surf      7      3271.0
# 7       surf      8      4662.0
# 8       surf      9      5968.0
# 9       surf     10      8020.0
# 10      surf     11      9165.0
# 11      surf     12     12275.0
# 12  ultimate      1        62.0
# 13  ultimate      2       151.0
# 14  ultimate      3       243.0
# 15  ultimate      4       463.0
# 16  ultimate      5       931.0
# 17  ultimate      6      1379.0
# 18  ultimate      7      1937.0
# 19  ultimate      8      2732.0
# 20  ultimate      9      3259.0
# 21  ultimate     10      4181.0
# 22  ultimate     11      4903.0
# 23  ultimate     12      6796.0

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df_num_msg_mes, x="month", y="numero_msg", hue="plan_name")
plt.title("Qtde msg por cliente mensal")
plt.xlabel("meses")
plt.ylabel("qtde msg mensal")

plt.legend(title="plano")
plt.show()

# %%
# os usuários do plano "surf" utilizaram mais mensagens a partir de março.

# %% [markdown]
# [Formule conclusões sobre como os usuários costumam consumir o tráfego da internet. O comportamento é diferente dependendo do plano?]

# %% [markdown]
# ### Internet

# %%
df_qtde_dados_mes = df_merge5.groupby(['plan_name', 'month'])["gb_used"].sum().reset_index(name= "qtde_dados")# Compare a quantidade de tráfego de internet consumido pelos usuários por plano

df_qtde_dados_mes
# Out:
#    plan_name  month   qtde_dados
# 0       surf      1     9.521211
# 1       surf      2   107.040615
# 2       surf      3   299.751094
# 3       surf      4   585.166162
# 4       surf      5  1047.948564
# 5       surf      6  1449.461260
# 6       surf      7  1983.218428
# 7       surf      8  2657.073906
# 8       surf      9  3143.298506
# 9       surf     10  4006.627354
# 10      surf     11  4515.633789
# 11      surf     12  5630.981699
# 12  ultimate      1    27.023799
# 13  ultimate      2   117.091465
# 14  ultimate      3   214.705293
# 15  ultimate      4   330.619873
# 16  ultimate      5   470.810537
# 17  ultimate      6   703.986611
# 18  ultimate      7   941.738203
# 19  ultimate      8  1235.200322
# 20  ultimate      9  1425.203887
# 21  ultimate     10  1823.174473
# 22  ultimate     11  2112.576211
# 23  ultimate     12  2701.955049

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df_qtde_dados_mes, x="month", y="qtde_dados", hue="plan_name")
plt.title("Qtde dados por cliente mensal")
plt.xlabel("meses")
plt.ylabel("qtde dados mensal")

plt.legend(title="plano")
plt.show()

# %%
#igual as mensagens, os usuários do plano "surf" usaram mais dados a partir de março em relação ao plano "ultimate"

# %% [markdown]
# [Formule conclusões sobre como os usuários tendem a consumir o tráfego da internet. O comportamento é diferente dependendo do plano?]

# %% [markdown]
# ## Receita

# %% [markdown]
# [Da mesma forma que você estudou o comportamento dos usuários, descreva estatisticamente as receitas dos planos.]

# %%
df_merge5["total_rev"]= df_merge5["usd_monthly_pay"]+df_merge5["rev_msg"]+df_merge5["rev_data"]+df_merge5["rev_min"]
df_merge5
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used plan_name  \
# 0        1000     12       16.0     11.0    116.83   1.856904  ultimate
# 1        1006     11        2.0     15.0      9.32   2.019893  ultimate
# 2        1006     12        9.0    139.0     54.79  31.366035  ultimate
# 3        1008     10       71.0     21.0    450.21  16.706045  ultimate
# 4        1008     11       63.0     37.0    422.81  23.121797  ultimate
# ...       ...    ...        ...      ...       ...        ...       ...
# 2288     1194     12        NaN     56.0       NaN  30.359854      surf
# 2289     1349     10        NaN     76.0       NaN  12.786670      surf
# 2290     1349     11        NaN     72.0       NaN  16.726816      surf
# 2291     1349     12        NaN     61.0       NaN  12.734287      surf
# 2292     1361      5        NaN      2.0       NaN   1.484072      surf
#
#       messages_included  mb_per_month_included  minutes_included  ...  \
# ...

# %%
df_receita_mes = df_merge5.groupby(['plan_name', 'month'])["total_rev"].sum().reset_index(name= "total_rev")
df_receita_mes
# Out:
#    plan_name  month     total_rev
# 0       surf      1     40.000000
# 1       surf      2    297.035600
# 2       surf      3   1002.312133
# 3       surf      4   1938.874258
# 4       surf      5   3491.678287
# 5       surf      6   4454.303370
# 6       surf      7   7159.723945
# 7       surf      8   9825.320625
# 8       surf      9  10655.194925
# 9       surf     10  14610.214048
# 10      surf     11  15545.777833
# 11      surf     12  21102.687315
# 12  ultimate      1    280.000000
# 13  ultimate      2    490.000000
# 14  ultimate      3    880.709375
# 15  ultimate      4   1528.198916
# 16  ultimate      5   2044.955869
# 17  ultimate      6   3359.418057
# 18  ultimate      7   4239.174434
# 19  ultimate      8   5160.287275
# 20  ultimate      9   6175.858623
# 21  ultimate     10   7641.719053
# 22  ultimate     11   9093.352871
# 23  ultimate     12  11029.902871

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df_receita_mes, x="month", y="total_rev", hue="plan_name")
plt.title("Receita mensal por plano")
plt.xlabel("meses")
plt.ylabel("Receita mensal")

plt.legend(title="plano")
plt.show()

# %%
df_media_plan = df_receita_mes.groupby('plan_name')["total_rev"].mean().reset_index()
df_media_plan
# Out:
#   plan_name    total_rev
# 0      surf  7510.260195
# 1  ultimate  4326.964779

# %%
#receita maior no plano surf provavelmente também por ter mais clientes

# %%
#Receita maior no plano Surf provavelmente pela necessidade dos clinetes terem que usar mais dados, mais chamadas e mais mensagens adicionais o que faz terem que pagar pelo uso a mais do plano.

# %% [markdown]
# [Formule conclusões sobre como a receita difere entre os planos.]

# %% [markdown]
# ## Teste hipóteses estatísticas

# %% [markdown]
# [Teste a hipótese de que a receita média dos usuários dos planos Ultimate e Surf são diferentes.]

# %% [markdown]
# [Formule as hipóteses nula e alternativa, escolha o teste estatístico, escolha o valor alfa.]

# %%
# H₀: A receita média dos usuários dos planos Ultimate e Surf é igual.          # Teste as hipóteses
# H₁: A receita média dos usuários dos planos Ultimate e Surf é diferente.
# α=0.05
# Teste= ttest

# %%
df_merge5[df_merge5["plan_name"]=="surf"]["total_rev"].mean()
# Out:
# 57.29378406756595

# %%
df_merge5[df_merge5["plan_name"]=="ultimate"]["total_rev"].mean()
# Out:
# 72.11607964409723

# %%
np.std(df_merge5.query('plan_name == "surf"')["total_rev"])
# Out:
# 53.71879818196207

# %%
np.std(df_merge5.query('plan_name == "ultimate"')["total_rev"])
# Out:
# 10.761366725632108

# %%
alpha=0.05
sample1=df_merge5.query('plan_name == "surf"')["total_rev"]
sample2=df_merge5.query('plan_name == "ultimate"')["total_rev"]
results= st.ttest_ind(sample1,sample2,equal_var=False)
print("pvalue:",results.pvalue)
if results.pvalue < alpha:
    print("rejeita a hipotese nula")
else:
    print("não rejeitar a hipotese nula")
# Out:
# pvalue: 4.881852673479904e-25
# rejeita a hipotese nula

# %%
df_merge5 = df_merge5.merge(df_users[['user_id', 'city']], on='user_id', how='left')

df_merge5
# Out:
#       user_id  month  num_calls  num_msg  duration    gb_used plan_name  \
# 0        1000     12       16.0     11.0    116.83   1.856904  ultimate
# 1        1006     11        2.0     15.0      9.32   2.019893  ultimate
# 2        1006     12        9.0    139.0     54.79  31.366035  ultimate
# 3        1008     10       71.0     21.0    450.21  16.706045  ultimate
# 4        1008     11       63.0     37.0    422.81  23.121797  ultimate
# ...       ...    ...        ...      ...       ...        ...       ...
# 2288     1194     12        NaN     56.0       NaN  30.359854      surf
# 2289     1349     10        NaN     76.0       NaN  12.786670      surf
# 2290     1349     11        NaN     72.0       NaN  16.726816      surf
# 2291     1349     12        NaN     61.0       NaN  12.734287      surf
# 2292     1361      5        NaN      2.0       NaN   1.484072      surf
#
#       messages_included  mb_per_month_included  minutes_included  ...  \
# ...

# %% [markdown]
# [Teste a hipótese de que a receita média dos usuários da área de NY-NJ difere dos usuários das demais regiões.]

# %% [markdown]
# [Formule as hipóteses nula e alternativa, escolha o teste estatístico, escolha o valor alfa.]

# %%
# H₀: A receita média dos usuários da área de NY-NJ não difere das demais.          
# H₁: A receita média dos usuários da área de NY-NJ difere das demais
# α=0.05
# Teste= ttest

# %%
mean1= df_merge5[df_merge5['city'].str.contains('ny-nj')]["total_rev"].mean()
mean1
# Out:
# 57.19048435842175

# %%
mean2= df_merge5[~df_merge5['city'].str.contains('ny-nj')]["total_rev"].mean()
mean2
# Out:
# 62.884074675838335

# %%
var1=df_merge5[df_merge5['city'].str.contains('ny-nj')]["total_rev"].var()
var1
# Out:
# 1777.7529232966267

# %%
var2=df_merge5[~df_merge5['city'].str.contains('ny-nj')]["total_rev"].var()
var2
# Out:
# 2116.1719888966627

# %%
#variâncias são diferentes, logo o "equal_var" será igual a False

# %%
# Teste as hipóteses

alpha=0.05
sample3=df_merge5[df_merge5['city'].str.contains('ny-nj')]["total_rev"]
sample_other_regions = df_merge5[~df_merge5['city'].str.contains('ny-nj')]["total_rev"]
results= st.ttest_ind(sample3,sample_other_regions,equal_var=False)
print("pvalue:",results.pvalue)
if results.pvalue < alpha:
    print("rejeita a hipotese nula")
else:
    print("não rejeitar a hipotese nula")
# Out:
# pvalue: 0.01860947297497194
# rejeita a hipotese nula

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
#  - Precisa avaliar as variâncias das amostras para configurar o parâmetro equal_var assim como você fez no teste anterior
#  - Oriento usar df['city'].str.contains('ny-nj') pois assim a busca é mais ampla
#  - Erro de execução no código com variável não definida
# </div>

# %% [markdown]
# </div>
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor v2: </b> <a class="tocSkip"></a>
#
# correto
#
# </div>

# %% [markdown]
# ## Conclusão geral
#
# [Liste suas conclusões importantes nesta seção final, certifique-se de que elas cobrem todas as decisões (suposições) importantes que você tomou e que levaram à maneira como você processou e analisou os dados.]

# %%
#Pude constatar que o plano Surf gera mais receita aparentemente por ter mais clientes no plano. Entretanto, em média, o plano Ultimate é mais rentável. Puder ver também que A receita média dos usuários da área de NY-NJ difere das demais o que leva a empresa a querer olhar com atenção aos planos por região.A receita de dados, min e msg apresentam uma semelhança no que diz respeito ao uso
